# %%
import pandas as pd

# %%
df_amazonsales = pd.read_csv('Amazon Sale Report.csv')

# %%
df_amazonsales
# Out:
#          index             Order ID      Date                        Status  \
# 0            0  405-8078784-5731545  04-30-22                     Cancelled
# 1            1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2            2  404-0687676-7273146  04-30-22                       Shipped
# 3            3  403-9615377-8133951  04-30-22                     Cancelled
# 4            4  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 128971  128970  406-6001380-7673107  05-31-22                       Shipped
# 128972  128971  402-9551604-7544318  05-31-22                       Shipped
# 128973  128972  407-9547469-3152358  05-31-22                       Shipped
# 128974  128973  402-6184140-0545956  05-31-22                       Shipped
# 128975  128974  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df_amazonsales_sorted = df_amazonsales.sort_values(['Date', 'Amount'], ascending=False)

# %%
df_amazonsales_sorted
# Out:
#        index             Order ID      Date     Status Fulfilment  \
# 91426  91425  403-8512624-0554733  06-29-22    Pending   Merchant
# 91569  91568  171-3739098-8680340  06-29-22    Shipped     Amazon
# 91626  91625  404-9701241-4689164  06-29-22    Shipped     Amazon
# 91376  91375  403-7199736-1093952  06-29-22    Pending     Amazon
# 91212  91211  171-1527731-1523559  06-29-22    Pending     Amazon
# ...      ...                  ...       ...        ...        ...
# 48933  48932  403-6645310-0040341  03-31-22  Cancelled     Amazon
# 48983  48982  406-3908087-4335510  03-31-22  Cancelled     Amazon
# 49007  49006  171-1556000-8993931  03-31-22  Cancelled     Amazon
# 49008  49007  403-9536559-5724368  03-31-22  Cancelled     Amazon
# 49049  49048  407-1754629-8915563  03-31-22  Cancelled     Amazon
#
#       Sales Channel ship-service-level Category Size Courier Status  ...  \
# 91426     Amazon.in           Standard    Shirt  4XL      Unshipped  ...
# ...

# %%
df_amazonsales_sorted.describe()
# Out:
#                index            Qty         Amount  ship-postal-code  New  \
# count  128976.000000  128976.000000  121176.000000     128941.000000  0.0
# mean    64486.130427       0.904401     648.562176     463945.677744  NaN
# std     37232.897832       0.313368     281.185041     191458.488954  NaN
# min         0.000000       0.000000       0.000000     110001.000000  NaN
# 25%     32242.750000       1.000000     449.000000     382421.000000  NaN
# 50%     64486.500000       1.000000     605.000000     500033.000000  NaN
# 75%     96730.250000       1.000000     788.000000     600024.000000  NaN
# max    128974.000000      15.000000    5584.000000     989898.000000  NaN
#
#        PendingS
# count       0.0
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %%
df_amazonsales_sorted.columns
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel',
#        'ship-service-level', 'Category', 'Size', 'Courier Status', 'Qty',
#        'currency', 'Amount', 'ship-city', 'ship-state', 'ship-postal-code',
#        'ship-country', 'B2B', 'fulfilled-by', 'New', 'PendingS'],
#       dtype='object')

# %%
df_amazonsales_sorted['Status'].value_counts()
# Out:
# Status
# Shipped                          77815
# Shipped - Delivered to Buyer     28756
# Cancelled                        18334
# Shipped - Returned to Seller      1954
# Shipped - Picked Up                973
# Pending                            658
# Pending - Waiting for Pick Up      281
# Shipped - Returning to Seller      145
# Shipped - Out for Delivery          35
# Shipped - Rejected by Buyer         11
# Shipping                             8
# Shipped - Lost in Transit            5
# Shipped - Damaged                    1
# Name: count, dtype: int64

# %%
df_amazonsales_sorted['Fulfilment'].value_counts()
# Out:
# Fulfilment
# Amazon      89713
# Merchant    39263
# Name: count, dtype: int64

# %%
df_amazonsales_sorted['ship-service-level'].value_counts()
# Out:
# ship-service-level
# Expedited    88630
# Standard     40346
# Name: count, dtype: int64

# %%
df_amazonsales_sorted['Category'].value_counts()
# Out:
# Category
# T-shirt     50292
# Shirt       49877
# Blazzer     15500
# Trousers    10616
# Perfume      1157
# Wallet        926
# Socks         440
# Shoes         165
# Watch           3
# Name: count, dtype: int64

# %%
df_amazonsales_sorted['Size'].value_counts()
# Out:
# Size
# M       22373
# L       21807
# XL      20549
# XXL     17806
# S       16776
# 3XL     14643
# XS      11056
# Free     2251
# 6XL       738
# 5XL       550
# 4XL       427
# Name: count, dtype: int64

# %%
df_amazonsales_sorted['Courier Status'].value_counts()
# Out:
# Courier Status
# Shipped       109486
# On the Way      6870
# Unshipped       6680
# Cancelled       5940
# Name: count, dtype: int64

# %%
df_amazonsales_sorted['Qty'].value_counts()
# Out:
# Qty
# 1     115779
# 0      12810
# 2        340
# 3         32
# 4          9
# 5          2
# 15         1
# 9          1
# 13         1
# 8          1
# Name: count, dtype: int64

# %%
df_amazonsales_sorted['ship-city'].value_counts()
# Out:
# ship-city
# BENGALURU               11208
# HYDERABAD                8077
# MUMBAI                   6125
# NEW DELHI                5792
# CHENNAI                  5430
#                         ...
# Wakad,Pune                  1
# Hebri                       1
# AHMADNAGARA                 1
# Allapra, Perumbavoor        1
# Chandauli UP                1
# Name: count, Length: 8948, dtype: int64

# %%
df_amazonsales_sorted['ship-state'].value_counts()
# Out:
# ship-state
# MAHARASHTRA      22272
# KARNATAKA        17324
# TAMIL NADU       11488
# TELANGANA        11330
# UTTAR PRADESH    10646
#                  ...
# Pondicherry          1
# Rajsthan             1
# rajsthan             1
# Mizoram              1
# APO                  1
# Name: count, Length: 69, dtype: int64

# %%
df_amazonsales_sorted['B2B'].value_counts()
# Out:
# B2B
# False    128104
# True        872
# Name: count, dtype: int64

# %%
df_amazonsales_sorted['ship-postal-code'].value_counts()
# Out:
# ship-postal-code
# 201301.0    1008
# 122001.0     686
# 560037.0     632
# 560068.0     613
# 560076.0     582
#             ...
# 733124.0       1
# 764037.0       1
# 160054.0       1
# 501503.0       1
# 605652.0       1
# Name: count, Length: 9454, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df_pivot = df_amazonsales_sorted.pivot_table(columns='Category', values='Qty', aggfunc='count')

# %%
df_pivot
# Out:
# Category  Blazzer  Perfume  Shirt  Shoes  Socks  T-shirt  Trousers  Wallet  \
# Amount      14703     1091  46713    156    420    47049     10160     881
#
# Category  Watch
# Amount        3

# %%
df_pivot.plot(kind='bar', xlabel='Category', ylabel='Qty', title='Quantity sold by Categories', figsize=(10,9))
# Out:
# <Axes: title={'center': 'Quantity sold by Categories'}, xlabel='Category', ylabel='Qty'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(columns='Category', values='Amount', aggfunc='sum')

# %%
df_pivot
# Out:
# Category      Blazzer    Perfume        Shirt      Shoes     Socks  \
# Amount    11215104.12  789419.66  21297770.08  124752.76  150757.5
#
# Category      T-shirt   Trousers     Wallet  Watch
# Amount    39206756.65  5346286.3  458408.18  915.0

# %%
df_pivot.plot(kind='bar', xlabel='Category', ylabel='Amount', title='Income by Categories', figsize=(10,8))
# Out:
# <Axes: title={'center': 'Income by Categories'}, xlabel='Category', ylabel='Amount'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(columns='Size', values='Amount', aggfunc='sum')

# %%
df_pivot
# Out:
# Size          3XL        4XL        5XL        6XL       Free            L  \
# Amount  9034156.3  334451.64  425156.63  576249.33  1373495.6  13039824.03
#
# Size              M            S           XL          XS          XXL
# Amount  13692642.13  10427760.94  12255950.38  6965505.58  10464977.69

# %%
df_pivot.plot(kind='bar', xlabel='Size', ylabel='Amount', title='Income by size', figsize=(10,8))
# Out:
# <Axes: title={'center': 'Income by size'}, xlabel='Size', ylabel='Amount'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(columns='Size', values='Qty', aggfunc='count')

# %%
df_pivot
# Out:
# Size    3XL  4XL  5XL  6XL  Free      L      M      S     XL     XS    XXL
# Qty   14643  427  550  738  2251  21807  22373  16776  20549  11056  17806

# %%
df_pivot.plot(kind='bar', xlabel='Size', ylabel='Qty', title='Quantity Sold by size', figsize=(10,8))
# Out:
# <Axes: title={'center': 'Quantity Sold by size'}, xlabel='Size', ylabel='Qty'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(index='Fulfilment', values='Qty', aggfunc='count')

# %%
df_pivot
# Out:
#               Qty
# Fulfilment
# Amazon      89713
# Merchant    39263

# %%
df_pivot.plot(kind='bar', xlabel='Fulfilment', ylabel='Qty', title='Quantity by Method of fulfilment', figsize=(10,8))
# Out:
# <Axes: title={'center': 'Quantity by Method of fulfilment'}, xlabel='Fulfilment', ylabel='Qty'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(index='Fulfilment', values='Amount', aggfunc='sum')

# %%
df_pivot
# Out:
#                  Amount
# Fulfilment
# Amazon      54327540.00
# Merchant    24262630.25

# %%
df_pivot.plot(kind='bar', xlabel='Fulfilment', ylabel='Amount', title='Income by Fulfilment Method', figsize=(14,8))
# Out:
# <Axes: title={'center': 'Income by Fulfilment Method'}, xlabel='Fulfilment', ylabel='Amount'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(index='ship-service-level', values='Amount', aggfunc='sum')

# %%
df_pivot
# Out:
#                          Amount
# ship-service-level
# Expedited           54291154.00
# Standard            24299016.25

# %%
df_pivot.plot(kind='bar', xlabel='Amount', ylabel='ship-service-level', title='Income by Service Shipping Levels', figsize=(12,8))
# Out:
# <Axes: title={'center': 'Income by Service Shipping Levels'}, xlabel='Amount', ylabel='ship-service-level'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(index='ship-service-level', values='Qty', aggfunc='count')

# %%
df_pivot
# Out:
#                       Qty
# ship-service-level
# Expedited           88630
# Standard            40346

# %%
df_pivot.plot(kind='bar', xlabel='Qty', ylabel='ship-service-level', title='Quantity according to Service Shipping Level', figsize=(10,8))
# Out:
# <Axes: title={'center': 'Quantity according to Service Shipping Level'}, xlabel='Qty', ylabel='ship-service-level'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(index='Courier Status', values='Qty', aggfunc='count')

# %%
df_pivot
# Out:
#                    Qty
# Courier Status
# Cancelled         5940
# On the Way        6870
# Shipped         109486
# Unshipped         6680

# %%
df_pivot.plot(kind='line', xlabel='Amount', ylabel='Courier Status', title='Quantity according to Courier Status', figsize=(12,8))
# Out:
# <Axes: title={'center': 'Quantity according to Courier Status'}, xlabel='Amount', ylabel='Courier Status'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(index='ship-state', values='Qty', aggfunc='count')

# %%
df_pivot
# Out:
#                     Qty
# ship-state
# ANDAMAN & NICOBAR   256
# ANDHRA PRADESH     5427
# APO                   1
# AR                    1
# ARUNACHAL PRADESH   141
# ...                 ...
# goa                   5
# orissa                1
# punjab               14
# rajasthan             6
# rajsthan              1
#
# [69 rows x 1 columns]

# %%
df_pivot.plot(kind='bar', xlabel='Qty', ylabel='ship-state', title='Quantity of orders by State', figsize=(16,10))
# Out:
# <Axes: title={'center': 'Quantity of orders by State'}, xlabel='Qty', ylabel='ship-state'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(index='ship-state', values='Amount', aggfunc='sum')

# %%
df_pivot
# Out:
#                        Amount
# ship-state
# ANDAMAN & NICOBAR   157424.62
# ANDHRA PRADESH     3217859.86
# APO                      0.00
# AR                     493.00
# ARUNACHAL PRADESH    95235.00
# ...                       ...
# goa                   2467.00
# orissa                 597.00
# punjab                8622.00
# rajasthan             3946.00
# rajsthan               521.00
#
# [69 rows x 1 columns]

# %%
df_pivot.plot(kind='bar', xlabel='Amount', ylabel='ship-state', title='income by State', figsize=(18,10))
# Out:
# <Axes: title={'center': 'income by State'}, xlabel='Amount', ylabel='ship-state'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(index='B2B', values='Qty', aggfunc='count')

# %%
df_pivot
# Out:
#           Qty
# B2B
# False  128104
# True      872

# %%
df_pivot.plot(kind='pie', y='Qty', title= 'Quantities according to Business Type', figsize=(10,8))
# Out:
# <Axes: title={'center': 'Quantities according to Business Type'}, ylabel='Qty'>

# %%
df_pivot = df_amazonsales_sorted.pivot_table(index='B2B', values='Amount', aggfunc='sum')

# %%
df_pivot
# Out:
#             Amount
# B2B
# False  77998690.46
# True     591479.79

# %%
df_pivot.plot(kind='pie', y='Amount', title= 'Income according to Business Type', figsize=(10,8))
# Out:
# <Axes: title={'center': 'Income according to Business Type'}, ylabel='Amount'>
